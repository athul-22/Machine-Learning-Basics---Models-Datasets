# %% [markdown]
# Topics:
# • Reading an image file and converting it to a numpy array
# • Resizing an image
# • RGB to Grayscale conversion

# %%
import matplotlib. image as mpimg 
import matplotlib.pyplot as plt

# %%
img = mpimg.imread('/Users/athulnambiar/Desktop/PROJECTS/ML-YT/ML5/1.webp')

# %%
print(img.shape)
# Out:
# (1674, 2500, 3)

# %%
print(img)
# Out:
# [[[171 101  54]
#   [171 101  54]
#   [171 101  54]
#   ...
#   [164  97  58]
#   [164  97  60]
#   [164  97  60]]
#
#  [[171 101  54]
#   [171 101  54]
#   [171 101  54]
#   ...
#   [164  97  58]
#   [164  97  60]
#   [164  97  60]]
#
#  [[171 101  54]
#   [171 101  54]
#   [171 101  54]
#   ...
#   [164  97  58]
#   [164  97  60]
#   [164  97  60]]
#
#  ...
#
#  [[171 104  56]
#   [171 104  56]
#   [171 104  56]
#   ...
#   [161  87  37]
#   [161  87  37]
#   [161  87  37]]
#
#  [[171 104  56]
#   [171 104  56]
#   [171 104  56]
#   ...
#   [160  86  38]
#   [160  86  36]
#   [160  86  36]]
#
#  [[171 104  56]
#   [171 104  56]
#   [171 104  56]
#   ...
#   [160  86  38]
#   [160  86  36]
#   [160  86  36]]]

# %%
img_plot = plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
img  = Image.open('/Users/athulnambiar/Desktop/PROJECTS/ML-YT/ML5/1.webp')
img_resized = img.resize((200,200))
img_resized.save('resized_img.png')

# %%
new = mpimg.imread('resized_img.png')
old = mpimg.imread('/Users/athulnambiar/Desktop/PROJECTS/ML-YT/ML5/1.webp')

# %% [markdown]
# CONVERTING RGB IMAGE TO GREYSCALE

# %%
import cv2

# %%
img = cv2.imread('/Users/athulnambiar/Desktop/PROJECTS/ML-YT/ML5/1.webp')

# %%
img.shape
# Out:
# (1674, 2500, 3)

# %%
greyscale_image = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
greyscal_image.shape
# Out:
# (1674, 2500)

# %%
type(greyscal_image)
# Out:
# numpy.ndarray

# %%
plt.imshow(greyscal_image)
